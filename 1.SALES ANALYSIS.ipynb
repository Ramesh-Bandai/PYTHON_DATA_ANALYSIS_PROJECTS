# %% [markdown]
# "./" means in current directory

# %%
import pandas as pd

# %%
import os

# %% [raw]
# Reading a CSV file
# pd.read_csv(r"PASTE PATH OF FILE")

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\ALL_CSV_FILES\Sales_April_2019.csv")

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [raw]
# Merging all files in one
#
# 1.creting list of all files present in a folder using od.listdir("PATH OF FOLDER WHERE ALL FILES PRESENT")
# 2.iterate thorough files  using for loop

# %%
from IPython.display import Image
Image(r"C:\Users\user\Downloads\.dir\Capture.PNG")

# %%
# ceating list of items prsent in folder sequentially
files= [file for file in os.listdir(r"C:\Users\user\Downloads\ALL_CSV_FILES")]

# %%
files
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
for file in files:
    print(file)
# Out:
# Sales_April_2019.csv
# Sales_August_2019.csv
# Sales_December_2019.csv
# Sales_February_2019.csv
# Sales_January_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv
# Sales_March_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_September_2019.csv

# %% [markdown]
# Concatneting files in one dataframe by creating empty dataframe

# %%
path = r'C:\Users\user\Downloads\ALL_CSV_FILES'
files = [file for file in os.listdir(path) if not file.startswith('.')] # Ignore hidden files

all_months_data = pd.DataFrame()

for file in files:
    current_data = pd.read_csv(path+"/"+file) # we must use /  not \ in path
    all_months_data = pd.concat([all_months_data, current_data])
    
all_months_data.to_csv("all_data_copy.csv", index=False) # saves in Notebook direcory otherwise specify path

# %%
all_months_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
all_months_data['date']=all_months_data['Order Date'].str[0:2] #takes colunn as string of first two letters
all_months_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address date
# ...

# %% [markdown]
# Find such a cell which contains nan values columnwise

# %%
# Find NAN
nan_df = all_months_data[all_months_data.isna().any(axis=1)]
nan_df.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address  \
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN
#
#      date
# 1     NaN
# 356   NaN
# 735   NaN
# 1433  NaN
# 1553  NaN

# %%
all_months_data= all_months_data.dropna(how='all') # 'all' means rows with eacch cell nan then and then only  & 'any' drops if single cell having Nan
all_months_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address date
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001   04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215   04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001   04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001   04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001   04

# %% [markdown]
# add a new column at last with constant value

# %%
all_months_data['New_column']=5
all_months_data.head()
# Out:
# <ipython-input-15-6f7dec45a0c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_months_data['New_column']=5
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address date  New_column
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001   04           5
# ...

# %% [markdown]
# searching for specific text matching or partially match

# %%
temp_df= all_months_data[all_months_data['Order Date'].str[0:2]=='Or']
temp_df
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1149   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1155   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2878   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2893   Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...         ...      ...               ...         ...         ...
# 10000  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 10387  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11399  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11468  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 11574  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#        Purchase Address date  New_column
# 519    Purchase Address   Or           5
# 1149   Purchase Address   Or           5
# ...

# %%
all_months_data=all_months_data[all_months_data['Order Date'].str[0:2]!='Or']
all_months_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address date  New_column
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001   04           5
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215   04           5
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001   04           5
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001   04           5
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001   04           5

# %% [markdown]
# Make columns correct type

# %%
all_months_data['Quantity Ordered'] = pd.to_numeric(all_months_data['Quantity Ordered']) # makes int
all_months_data['Price Each'] = pd.to_numeric(all_months_data['Price Each']) # makes flot

# %%
all_months_data['date'] = all_months_data['date'].astype('int32')
all_months_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  date  New_column  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001     4           5
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215     4           5
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     4           5
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     4           5
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001     4           5
#
#    Month
# 0      4
# 2      4
# 3      4
# 4      4
# 5      4

# %%
del all_months_data['New_column']

# %%
all_months_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  date  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001     4      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215     4      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     4      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     4      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001     4      4

# %%
del all_months_data['Month']
all_months_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  date
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001     4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215     4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001     4

# %% [markdown]
# Feature Extraction  splitting can be done by , or " " or both after splitting u get seperate part
# strip will remove indentation space before and after a seperated part

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_state(address):
    return address.split(",")[2].split(" ")[1]

all_months_data['City'] = all_months_data['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")
all_months_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  date  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001     4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215     4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001     4
#
#                 City
# 0       Dallas  (TX)
# 2       Boston  (MA)
# 3  Los Angeles  (CA)
# 4  Los Angeles  (CA)
# 5  Los Angeles  (CA)
